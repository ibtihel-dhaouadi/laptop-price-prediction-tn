# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from tqdm import tqdm
import time
import re

# %%
def scrape_products_from_page(url):
    response = requests.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    
    # Find all product name elements
    product_elements = soup.find_all('form', class_='product-item')
    #print(product_elements[0].prettify())

    products=[]
    # Extract and print the names
    for product in product_elements:
        try:
            # Product Link
            link_tag = product.find("a", class_="product-item-link")
            product_link = link_tag['href'] if link_tag else None
            
            # Product Full Name
            full_name = link_tag.text.strip() if link_tag else None
            
            # Image URL
            img_tag = product.find("img", class_="product-image-photo")
            image_url = img_tag['src'] if img_tag else None
            
            # Price
            price_tag = product.find("span", class_="price")
            price = price_tag.text.strip() if price_tag else None

            specs = {}
            #Additional data from product page
            if product_link:
                response = requests.get(product_link)
                if response.status_code == 200:                    
                    product_page = BeautifulSoup(response.text, 'html.parser')
                    table = product_page.find('table')  

                    for row in table.find_all('tr'):
                            cells = row.find_all(['td', 'th'])
                            if len(cells) >= 2:
                                key = cells[0].get_text(strip=True)
                                value = cells[1].get_text(strip=True)
                                specs[key] = value


            # Append product data
            product_dict = {
                "lien": product_link,
                "nom": full_name,
                "image_url": image_url,
                "prix": price,
                "boutique":"Batam"
            }

            # Add specs dictionary to product_data (expand keys dynamically)
            product_dict.update(specs)

            # Append to products list
            products.append(product_dict)
            
        except Exception as e:
            print(f"Error processing product: {e}")
   
    return products

# %%
base_url = "https://batam.com.tn/informatique/ordinateur-portable.html?p={}"
response = requests.get(base_url)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

# Find the first span with class toolbar-number
total_products_span = soup.select('p#toolbar-amount span.toolbar-number')

# Extract the number as int
total_products = int(total_products_span[-1].text) if total_products_span[-1] else 0

print("Total products:", total_products)
# Out:
# Total products: 114

# %%
# Initialize tqdm with total=total_products and initial=len(all_products)
pbar = tqdm(total=total_products, desc="Scraping products")

all_products = []

page_num = 1
while len(all_products) < total_products:
    url = base_url.format(page_num)
    page_products = scrape_products_from_page(url)  # your scraping function
    all_products.extend(page_products)
    # Update progress bar by number of new products scraped
    pbar.update(len(page_products))
    page_num += 1
    time.sleep(1)  # polite delay

pbar.close()
print(f"Total products scraped: {len(all_products)} / {total_products}")
# Out:
# Scraping products: 100%|█████████████████████████████████████████████████████████████| 114/114 [01:44<00:00,  1.09it/s]
# Total products scraped: 114 / 114

# %%
list(all_products[0].keys())
# Out:
# ['lien',
#  'nom',
#  'image_url',
#  'prix',
#  'boutique',
#  'Référence',
#  'Marque',
#  'Gamme pc',
#  'Gamer',
#  "Système d'exploitation",
#  "Taille de l'écran",
#  'Écran',
#  'Résolution écran',
#  'Écran tactile',
#  'Processeur',
#  'Type de processeur',
#  'Référence processeur',
#  'Fréquence processeur',
#  'Mémoire',
#  'Disque dur',
#  'Type de disque dur',
#  'Carte graphique',
#  'Chipset graphique',
#  'Connecteurs',
#  'Couleur',
#  'Garantie']

# %%
columns_to_keep = ['Référence', 'lien', 'nom', 'Marque', 'image_url', 'boutique', 'Taille de l\'écran',
                   'Résolution écran', 'Processeur', 'Référence processeur', 'Mémoire','Disque dur', 
                   'Type de disque dur', 'Carte graphique', "Système d'exploitation",'Gamer', 'prix']

# Filter the dictionary to keep only the desired columns
filtered_product_features = [{key: product.get(key) for key in columns_to_keep}
                             for product in all_products]

# %%
df = pd.DataFrame(filtered_product_features)
df.head()
# Out:
#       Référence                                               lien  \
# 0  X515KA-EJ008  https://batam.com.tn/asus-celeron-4-256-silver...
# 1    82QY00PEFE  https://batam.com.tn/pc-lenovo-n4500-8gb-256-s...
# 2    82LX00CKFG  https://batam.com.tn/pc-lenovon-celeron-8-256b...
# 3    82LX00CFFG  https://batam.com.tn/pc-lenovon-celeron-8-256b...
# 4    82LX00CEFG  https://batam.com.tn/pc-lenovo-celeron-8-256-w...
#
#                                                  nom  Marque  \
# 0  PC Portable  ASUS Intel Celeron N4500 4Go 256G...    ASUS
# 1  PC Portable LENOVO V15 G2 IJL Intel Celeron N4...  LENOVO
# 2  PC Portable LENOVO IdeaPad 1 15IJL7 Intel Cele...  LENOVO
# 3  PC Portable LENOVO IdeaPad 1 15IJL7 Intel Cele...  LENOVO
# 4  PC Portable LENOVO IdeaPad 1 15IJL7 Intel Cele...  LENOVO
#
#                                            image_url boutique  \
# 0  https://batam.com.tn/media/catalog/product/cac...    Batam
# 1  https://batam.com.tn/media/catalog/product/cac...    Batam
# 2  https://batam.com.tn/media/catalog/product/cac...    Batam
# 3  https://batam.com.tn/media/catalog/product/cac...    Batam
# 4  https://batam.com.tn/media/catalog/product/cac...    Batam
#
#   Taille de l'écran Résolution écran     Processeur   Référence processeur  \
# 0            15,6''      1920 x 1080  Intel Celeron  Intel® Celeron® N4500
# 1            15,6''      1920 x 1080  Intel Celeron  Intel® Celeron® N4500
# 2            15,6''       1366 x 768  Intel Celeron  Intel® Celeron® N4500
# 3            15,6''       1366 x 768  Intel Celeron  Intel® Celeron® N4500
# 4            15,6''       1366 x 768  Intel Celeron  Intel® Celeron® N4500
#
#   Mémoire Disque dur Type de disque dur     Carte graphique  \
# 0    4 Go      256GO                SSD  Graphique Intégrée
# 1    8 Go      256GO                SSD  Graphique Intégrée
# 2    8 Go      256GO                SSD  Graphique Intégrée
# 3    8 Go      256GO                SSD  Graphique Intégrée
# 4    8 Go      256GO                SSD  Graphique Intégrée
#
#   Système d'exploitation Gamer        prix
# 0                FreeDos   Non  629,000 DT
# 1                FreeDos   Non  729,000 DT
# 2                FreeDos   Non  729,000 DT
# 3                FreeDos   Non  729,000 DT
# 4     Windows 11 Famille   Non  735,000 DT

# %%
df.describe().T
# Out:
#                        count unique  \
# Référence                114    107
# lien                     114    114
# nom                      114    110
# Marque                   114      6
# image_url                114    114
# boutique                 114      1
# Taille de l'écran        114      6
# Résolution écran         102      8
# Processeur               114     18
# Référence processeur     105     38
# Mémoire                  114      6
# Disque dur               110      3
# Type de disque dur       113      1
# Carte graphique          103      5
# Système d'exploitation   114      6
# Gamer                    114      1
# prix                     114     74
#
#                                                                       top freq
# Référence                                                         9D6W0EA    2
# lien                    https://batam.com.tn/asus-celeron-4-256-silver...    1
# nom                     PC Portable HP 15-fd0048nk i5 13è Gén 8Go 512G...    2
# Marque                                                                 HP   33
# image_url               https://batam.com.tn/media/catalog/product/cac...    1
# boutique                                                            Batam  114
# Taille de l'écran                                                  15,6''   90
# Résolution écran                                              1920 x 1080   75
# Processeur                                                  Intel Core i5   36
# Référence processeur                                Intel® Core™ i5-1334U   14
# Mémoire                                                              8 Go   78
# Disque dur                                                          512GO   75
# Type de disque dur                                                    SSD  113
# Carte graphique                                        Graphique Intégrée   85
# Système d'exploitation                                            FreeDos   44
# Gamer                                                                 Non  114
# prix                                                         1 199,000 DT    6

# %%
# Save to CSV
df.to_csv("scraped_data/batam_products.csv", index=False, encoding='utf-8-sig')

print("Data saved to batam_products.csv")
# Out:
# Data saved to batam_products.csv
